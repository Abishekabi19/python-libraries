# %%
print("ansh if")
# Out:
# ansh if

# %%
a=1
print(a)
# Out:
# 1

# %%
1number=1
print(1number)
# Out:
#   File "/tmp/ipython-input-2231984477.py", line 1
#     1number=1
#     ^
# SyntaxError: invalid decimal literal

# %%
False=1
print(False)
# Out:
#   File "/tmp/ipython-input-4099992671.py", line 1
#     False=1
#     ^
# SyntaxError: cannot assign to False

# %%
xbgdfjDGFj=726
nhbdajKJNd=26
abcedjnfkm=xbgdfjDGFj*nhbdajKJNd
print(abcedjnfkm)
# Out:
# 18876

# %%
x=726
y=26
z=x*y
print(z)
# Out:
# 18876

# %%
payment_per_day=726
days_of_working=26
total_salary=payment_per_day*days_of_working
'''hghgjfhggf
hggj
hgjh'''
print(total_salary)
# Out:
# 18876

# %%
x='welcome'
print(type(x))
# Out:
# <class 'str'>

# %%
y=1234
print(type(y))
# Out:
# <class 'int'>

# %%
v=True
print(type(v))
# Out:
# <class 'bool'>

# %%
c=3+4j
print(type(c))
# Out:
# <class 'complex'>

# %%
deci=23.32
print(type(deci))
# Out:
# <class 'float'>

# %%
int(deci)
# Out:
# 23

# %%
float(y)
# Out:
# 1234.0

# %%
round(deci)
# Out:
# 23

# %%
l='hello'
k='miss'
j=l+k
print(j)
# Out:
# hellomiss

# %%
h='1254'
f=1236
s=int(h)
q=f+s
print(q)
# Out:
# 2490

# %% [markdown]
# #**String**

# %% [markdown]
# ## string as array

# %%
x='array'
print(x[2])
# Out:
# r

# %%
x='hello programmer'
print(len(x))           #space also count
# Out:
# 16

# %%
y="hello,let's start coding"
print('start' in y)
# Out:
# True

# %%
print('an' not in y)
# Out:
# True

# %% [markdown]
# ## slicing

# %%
ab='hy my name is python'
print(ab[2:10])
# Out:
#  my name

# %%
ab='hello python'
print(ab[1:])
# Out:
# ello python

# %%
a='hello, world!'
print(a[-5:-2])
# Out:
# orl

# %%
a='hy python'
print(a.upper())
# Out:
# HY PYTHON

# %%
b='hello, python'
print(b.replace('h','j'))
# Out:
# jello, pytjon

# %%
a='hello and hi world!'
print(a.split('and'))
# Out:
# ['hello ', ' hi world!']

# %%
s=' hello, world! '
print(s.strip())
# Out:
# hello, world!

# %% [markdown]
# ## string format

# %%
age=36
txt='my name is john,and i am {}'
print(txt.format(age))
# Out:
# my name is john,and i am 36

# %%
amt=5000
order=375
quantity=5
myorder='i want {} of my order {} for {} rupees'
print(myorder.format(quantity,order,amt))
# Out:
# i want 5 of my order 375 for 5000 rupees

# %%
txt= 'we are the so called \"vikings\" for the north'
print(txt)
# Out:
# we are the so called "vikings" for the north

# %% [markdown]
# ## python booleans

# %%
print(10==10)
print(10<9)
print(0)
# Out:
# True
# False
# 0

# %%
x=200
print(isinstance(x,str))
print(isinstance(x,int))
# Out:
# False
# True

# %% [markdown]
# # **Operators**

# %% [markdown]
# ## arithematic operator

# %%
x=4
y=8
import operator
operator.add(x,y)
# Out:
# 12

# %%
operator.sub(x,y)
# Out:
# -4

# %%
x=5
y=2
operator.pow(x,y)
# Out:
# 25

# %%
a=25
b=6
operator.truediv(a,b)
# Out:
# 4.166666666666667

# %%
a=25
b=6
operator.floordiv(a,b)
# Out:
# 4

# %% [markdown]
# ## assignment operator

# %%
a=25
b=14
operator.iadd(a,b)
# Out:
# 39

# %%
a=25
b=14
operator.isub(a,b)
# Out:
# 11

# %%
a=25
b=14
operator.imul(a,b)
# Out:
# 350

# %% [markdown]
# ## logical operator

# %%
a=10
v=20
a>12 and v>30         #both are true,both are false
# Out:
# False

# %%
a=10
v=20
a<12 or v>30          #atleast one is true
# Out:
# True

# %%
a=10
not a>20
# Out:
# True

# %% [markdown]
# ## identity operator

# %%
a=25
b=23
operator.is_(a,b)
# Out:
# False

# %%
a=25
b=23
operator.is_not(a,b)
# Out:
# True

# %% [markdown]
# ## membership operator

# %%
nums=(1,2,3,4,5)
operator.contains(nums,4)
# Out:
# True

# %%
nums=(1,2,3,4,5)
not operator.contains(nums,9)
# Out:
# True

# %% [markdown]
# # **Lists**

# %% [markdown]
# we use squared bracket

# %%
fruits=["apple","banana","kiwi","orange"]
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'orange']

# %%
fruits=["apple","banana","kiwi","orange"]
print(fruits[2])
# Out:
# kiwi

# %%
fruits=["apple","banana","kiwi","orange"]
print(fruits[1:3])
# Out:
# ['banana', 'kiwi']

# %%
fruits=["apple","banana","kiwi","orange"]
print(fruits[-2])
# Out:
# kiwi

# %%
fruits=["apple","banana","kiwi","orange"]
print(fruits[:3])
# Out:
# ['apple', 'banana', 'kiwi']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits[1]='mango'
print(fruits)
# Out:
# ['apple', 'mango', 'kiwi', 'orange']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits[1:3]="grape","draganfruit"
print(fruits)
# Out:
# ['apple', 'grape', 'draganfruit', 'orange']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits.insert(2,"cherry")                    #insert a new item, we can specify index
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits.append('cherry')                     #add a new item, it will be in last
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'orange', 'cherry']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits2=["mango","pineapple"]          #extend the current list
                                       #we can use tuple or set
fruits.extend(fruits2)
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'orange', 'mango', 'pineapple']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits.remove('kiwi')             #specified value remove
print(fruits)
# Out:
# ['apple', 'banana', 'orange']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits.pop(2)                     #specified position remove
print(fruits)
# Out:
# ['apple', 'banana', 'orange']

# %%
fruits=["apple","banana","kiwi","orange"]
fruits.clear()
print(fruits)
# Out:
# []

# %% [markdown]
# # **Tuple**

# %% [markdown]
# we use open bracket, these are unchangeable

# %%
fruits=('apple','orange','grape','banana','cherry')
print(fruits)
# Out:
# ('apple', 'orange', 'grape', 'banana', 'cherry')

# %%
fruits=('apple','orange','grape','banana','cherry')
print(len(fruits))
# Out:
# 5

# %%
fruits=('apple','orange','grape','banana','cherry')
print(type(fruits))
# Out:
# <class 'tuple'>

# %%
fruits=('apple','orange','grape','banana','cherry')
print(fruits[1])
# Out:
# orange

# %%
fruits=('apple','orange','grape','banana','cherry')
(red,yellow,pink,black,blue)=fruits
print(red)
# Out:
# apple

# %% [markdown]
# # **Sets**

# %% [markdown]
# unordered, unindexed, unchangeable.
# Written with curly brackets.

# %%
fruits={'apple','orange','grape','banana','cherry'}
print(fruits)
# Out:
# {'orange', 'apple', 'grape', 'banana', 'cherry'}

# %%
fruits={'apple','orange','grape','banana','cherry'}
fruits.add('pineapple')
print(fruits)
# Out:
# {'orange', 'pineapple', 'apple', 'grape', 'banana', 'cherry'}

# %%
fruits={'apple','orange','grape','banana','cherry'}
mylist=('kiwi','draganfruit')
fruits.update(mylist)
print(fruits)
# Out:
# {'orange', 'draganfruit', 'apple', 'grape', 'kiwi', 'banana', 'cherry'}

# %%
set1={'a','b','c','d'}
set2={1,2,3,4}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 'b', 'd', 2, 3, 4, 'a', 'c'}

# %%
set1={'a','b','c','d'}
set2={1,2,3,4}
set1.update(set2)
print(set1)
# Out:
# {1, 'b', 'd', 2, 3, 4, 'a', 'c'}

# %%
x={'apple','mango','grape'}
y={'kiwi','cherry','mango'}
x.intersection_update(y)
print(x)
# Out:
# {'mango'}

# %%
x={'apple','mango','grape'}
y={'kiwi','cherry','mango'}
z=x.intersection(y)
print(z)
# Out:
# {'mango'}

# %%
x={'apple','mango','grape'}
y={'kiwi','cherry','mango'}
x.symmetric_difference_update(y)
print(x)
# Out:
# {'grape', 'cherry', 'apple', 'kiwi'}

# %%
x={'apple','mango','grape'}
y={'kiwi','cherry','mango'}
z=x.symmetric_difference(y)
print(z)
# Out:
# {'grape', 'cherry', 'apple', 'kiwi'}

# %% [markdown]
# # **Frozenset**

# %%
x=(1,2,3,4,5,6,7,8)
fx=frozenset(x)
print(fx)
# Out:
# frozenset({1, 2, 3, 4, 5, 6, 7, 8})

# %% [markdown]
# # **Dictionaries**

# %% [markdown]
# these store values in key- value pair.
# Dictionaries are written with curly brackets, and have keys and values.dictionary is a collection which is ordered, changeable and does not allow duplicates.

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
print(cars)
# Out:
# {'brand': 'BMW', 'model': '2nd series', 'year': 2004}

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
print(cars['model'])
# Out:
# 2nd series

# %%
x=cars.get('brand')
print(x)
# Out:
# BMW

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
x=cars.keys()
print(x)
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
x=cars.values()
print(x)
# Out:
# dict_values(['BMW', '2nd series', 2004])

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
cars['year']=2023
x=cars.values()
print(x)
# Out:
# dict_values(['BMW', '2nd series', 2023])

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
cars['color']='blue'
x=cars.values()
print(x)
# Out:
# dict_values(['BMW', '2nd series', 2004, 'blue'])

# %%
y=cars.items()
print(y)
# Out:
# dict_items([('brand', 'BMW'), ('model', '2nd series'), ('year', 2004), ('color', 'blue')])

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
cars['year']=1998
print(cars)
# Out:
# {'brand': 'BMW', 'model': '2nd series', 'year': 1998}

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
cars.update({'year':1998})
print(cars)
# Out:
# {'brand': 'BMW', 'model': '2nd series', 'year': 1998}

# %%
cars={'brand':'BMW',
      'model':'2nd series',
      'year':2004}
x=cars.copy()
print(x)
# Out:
# {'brand': 'BMW', 'model': '2nd series', 'year': 2004}

# %%
friends={'child1':{
    'name':'abi',
    'year':2000},

         'child2':{'name':'rino',
         'year':2001},

         'child3':{'name':'aju',
         'year':2002}
         }
print(friends)
# Out:
# {'child1': {'name': 'abi', 'year': 2000}, 'child2': {'name': 'rino', 'year': 2001}, 'child3': {'name': 'aju', 'year': 2002}}

# %%
child1={
    'name':'abi',
    'year':2000}

child2={'name':'rino',
         'year':2001}

child3={'name':'aju',
         'year':2002}
friends={'a':child1,
         'b':child2,
         'c':child3}

# %% [markdown]
# # **Conditional statements**

# %%
a=20
b=200
if b>a:
print('b is greater than a')
# Out:
#   File "/tmp/ipython-input-3134007963.py", line 4
#     print('b is greater than a')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
a=20
b=200
if b>a:
 print('b is greater than a')
# Out:
# b is greater than a

# %%
a=20
b=20
if b>a:
    print('b is greater than a')
elif a==b:
  print('a and b are equal')
# Out:
# a and b are equal

# %%
a=299
b=300
if a>b:
  print('a is greater than b')
elif a==b:
  print('a and b are equal')
else:
  print('a is less than b')
# Out:
# a is less than b

# %%
a=299
b=300
print('A') if a>b else print('B')
# Out:
# B

# %%
a=33
b=330
print('a') if a>b else print('j') if a==b else print('c')
# Out:
# c

# %%
a=200
b=99
c=300
if a>b and c>a:
  print('both conditions are true')   #code will execute when both the statements are true.
# Out:
# both conditions are true

# %%
a=200                 # will execute when one condition true.

b=99
c=300
if a>b or c<a:
  print('atleast one of the condition is true')
# Out:
# atleast one of the condition is true

# %%
x=41
if x>10:
 	 	print("Above ten,")
if x>20:
  	print("and also above 20!")
else:
 print("but not above 20")
# Out:
# Above ten,
# and also above 20!

# %%
a=300
b=230
if a>b:
  pass

# %%
mark=int(input("enter: "))
# Out:
# password: 26

# %%
mark=int(input("Grade: "))
if mark>=90:
  print('A+')
elif mark>=80:
  print('A')
elif mark>=70:
  print('B+')
elif mark>=60:
  print('B')
elif mark>=50:
  print('C+')
elif mark<50:
  print('fail')
# Out:
# Grade: 87
# A

# %% [markdown]
# # **Looping statement**

# %% [markdown]
# ## while loop

# %%
x=0
while x<5:
  print(x)
  x=x+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x=5
while x<10:
  print(x)
  x=x+2
# Out:
# 5
# 7
# 9

# %%
x=0
while x<5:
  print(x)
  x=x+1
  continue
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x=1
while x<5:
  print(x)
  x=x+1
  break
# Out:
# 1

# %%
x=0
while x<5:
  print(x)
  x=x+1
else:
  print('no break')
# Out:
# 0
# 1
# 2
# 3
# 4
# no break

# %%
x=0
a='loop in python'
while x<len(a):
  if a[x]=="p":
    x=x+1
    continue
  else:
    print(a[x])
    x=x+1
# Out:
# l
# o
# o
#
# i
# n
#
# y
# t
# h
# o
# n

# %%
x=0
a='loop in python'
while x<len(a):
  if a[x]=="p":
    x=x+1
    continue
  else:
    print(a[x])
    x=x+3
# Out:
# l
#
#
# t
# n

# %%
x=0
a='loop in python'
while x<len(a):
  if a[x]=="p":
    x=x+2
    continue
  else:
    print(a[x])
    x=x+1
# Out:
# l
# o
# o
# i
# n
#
# t
# h
# o
# n

# %%
x=0
a='loop in python'
while x<len(a):
  if a[x]=="o":
    x=x+1
    break
  else:
    print(a[x])
    x=x+1
# Out:
# l

# %%
x=0
a='loop in python'
while x<len(a):
  if a[x]=='o' or a[x]=='p':
   x=x+1
   continue
  else:
    print('current letter:',a[x])
    x=x+1
# Out:
# current letter: l
# current letter:
# current letter: i
# current letter: n
# current letter:
# current letter: y
# current letter: t
# current letter: h
# current letter: n

# %%
x=0
a='loop in python'
while x<len(a):
  if a[x]=='p' or a[x]=='n':
   x=x+1
   break
  else:
    print('current letter:',a[x])
  x=x+1
# Out:
# current letter: l
# current letter: o
# current letter: o

# %% [markdown]
# ## for loop

# %%
b=('apple','orange','mango')
for c in b:
  print(c)
# Out:
# apple
# orange
# mango

# %%
for x in 'python developer':
  if x=="p" or x=='e':
    continue
  else:
    print(x)
# Out:
# y
# t
# h
# o
# n
#
# d
# v
# l
# o
# r

# %%
for x in 'python developer':
  if x=="e":
    break
  else:
    print(x)
# Out:
# p
# y
# t
# h
# o
# n
#
# d

# %%
for x in 'python developer':
  pass
print(x)
# Out:
# r

# %%
for x in range(5):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=[12,13,14,15]
for i in range(len(a)):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
a=[12,13,14,15]
for i in range(len(a)):
  print(a[i])
# Out:
# 12
# 13
# 14
# 15

# %%
sum=0
for x in range(11):
   sum=sum+x
print(sum)
# Out:
# 55

# %%
for x in range(5):
  print(x)
else:
  print('no')
# Out:
# 0
# 1
# 2
# 3
# 4
# no

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ### nested loop

# %%
fruits=['apple','orange','mango']
color=['red','blue','yellow']
for x in fruits:
  for y in color:
     print(x,y)
# Out:
# apple red
# apple blue
# apple yellow
# orange red
# orange blue
# orange yellow
# mango red
# mango blue
# mango yellow

# %% [markdown]
# # **Python Functions**

# %%
def hello():
  print('hi all')
hello()
# Out:
# hi all

# %%
def even_or_odd(x):
  if x%2==0:
    print('even')
  else:
    print('odd')
even_or_odd(5)
even_or_odd(6)
even_or_odd(9)
# Out:
# odd
# even
# odd

# %%
#python program to demonstrate default arguments

def num(x,y=20):
  print('x',x)
  print('y',y)
num(52)
# Out:
# x 52
# y 20

# %%
# to demonstrate keyword arguments

def name(firstname,lastname):
  print(firstname,lastname)
name(firstname='abishek',lastname='N')
name(lastname='N',firstname='abishek')
# Out:
# abishek N
# abishek N

# %%
def my(*kids):
  print('the youngest child is',kids[2])
my('abi','emil','linus')
# Out:
# the youngest child is linus

# %%
def my(*kids):
  for i in kids:
    print(i)
my('abi','naj','asd')
# Out:
# abi
# naj
# asd

# %%
def my(**student):
  print('his first name is',student['fname'])
my(fname='abishek',lname='N')
# Out:
# his first name is abishek

# %%
# IF we call the function without argument,it uses the default value

def my(country='india'):
  print('i am from',country)
my('sweden')
my('brazil')
my()
my('iran')
# Out:
# i am from sweden
# i am from brazil
# i am from india
# i am from iran

# %%
def my(xys):
  for i in xys:
    print(i)
frt=['apple','banana','orange']
my(frt)
# Out:
# apple
# banana
# orange

# %%
def sq_value(num):
  return num+2
print(sq_value(2))
print(sq_value(4))
# Out:
# 4
# 6

# %%
def my(x):
  x[1]=30
lst=[1,23,43,67]
my(lst)
print(lst)
# Out:
# [1, 30, 43, 67]

# %%
def f1():
  s='hello all'
  def f2():
   print(s)
  f2()
f1()
# Out:
# hello all

# %% [markdown]
# ## lambda function
# it is an anonymous funtion.
#
# lambda argument:expression
#
# any number of argument but only one expression

# %%
def cube(y):
  return y*y*y       # normal fun call

g= lambda x:x*x*x
print(g(7))
print(cube(5))
# Out:
# 343
# 125

# %%
def power(n):
  return lambda a:a**n
base = power(2)
print('now power is set to 2')
print('6 power of 2 =',base(6))

base =power(5)
print('now power is set to 5')
print('8 power of 5 =',base(8))
# Out:
# now power is set to 2
# 6 power of 2 = 36
# now power is set to 5
# 8 power of 5 = 32768

# %% [markdown]
# ### filter()

# %%
a=[2,5,7,12,8,90,100]
filtered =filter(lambda x:x%2==0,a)
print(list(filtered))
# Out:
# [2, 12, 8, 90, 100]

# %%
a=(2,5,7,12,8,90,100)
filtered =filter(lambda x:x<14,a)
print(tuple(filtered))
# Out:
# (2, 5, 7, 12, 8)

# %% [markdown]
# ### map()

# %%
a=[2,3,5,7,12,14,67,71]
maped=map(lambda x:x%2==0,a)
print(list(maped))
# Out:
# [True, False, False, False, True, True, False, False]

# %% [markdown]
# ## global and local variable

# %%
#Global variables are the one that is defined and declared outside a function and
#we need to use them inside a function

def my():
  print(s)
s='hi python'
my()
# Out:
# hi python

# %%
def my():
  s='me too'
  print(s)
s='hi python'
my()
print(s)
# Out:
# me too
# hi python

# %%
a=1
def f():
  print('inside f():',a)
def g():
  a=2
  print('inside g():',a)
def h():
  global a
  a=3
  print('inside h():',a)
print('global:',a)
f()
print('global:',a)
g()
print('global:',a)
h()
print('global:',a)
# Out:
# global: 1
# inside f(): 1
# global: 1
# inside g(): 2
# global: 1
# inside h(): 3
# global: 3

# %% [markdown]
# ## First class funtions

# %% [markdown]
# ### functions are objects

# %%
def shout(txt):
  return txt.upper()
print(shout('hello'))
yell=shout
print(yell('hello'))
# Out:
# HELLO
# HELLO

# %% [markdown]
# ### function can be passed as arguments to other function

# %%
def shout(txt):
  return txt.upper()
def whisper(txt):
  return txt.lower()
def greet(func):
  greeting=func('hi,i am created by a function passed as an argument')
  print(greeting)

greet(shout)
greet(whisper)
# Out:
# HI,I AM CREATED BY A FUNCTION PASSED AS AN ARGUMENT
# hi,i am created by a function passed as an argument

# %% [markdown]
# ### funtion can return another funtion

# %%
def create_adder(x):
  def adder(y):
    return x+y
  return adder
add_15=create_adder(15)
print(add_15(10))
# Out:
# 25

# %% [markdown]
# ## Recursive funtions

# %%
x=int(input())
def calc_factorial(x):
  if x==1:
    return 1
  else:
    return(x*calc_factorial(x-1))
print('the factorial of',x,"is",calc_factorial(x))
# Out:
# 5
# the factorial of 5 is 120

# %% [markdown]
# # **Class and Object**

# %%
class phone:
  def make_call(self):
    print("let's make a phone call")
  def play_game(self):                # method
    print("let's play a game")
p1=phone()                            # making object
p1.make_call()
p1.play_game()
# Out:
# let's make a phone call
# let's play a game

# %% [markdown]
# ## adding parameter to the class

# %%
class phone:

  def set_color(self,color):        # adding new parameter
    self.color=color
  def set_cost(self,cost):
    self.cost=cost
  def show_color(self):
    return self.color
  def show_cost(self):
    return self.cost
p2=phone()
p2.set_color('blue')
p2.show_color()
# Out:
# 'blue'

# %%
p2.set_cost(99999)
p2.show_cost()
# Out:
# 99999

# %% [markdown]
# ## creating a class with constructor

# %%
class employee:
  def __init__(self,name,age,salary,gender):    # init method
    self.name=name
    self.age=age
    self.salary=salary
    self.gender=gender

  def employee_details(self):
    print('name of employee is',self.name)
    print('age of employee is',self.age)
    print('salary of employee is',self.salary)
    print('gender of employee is',self.gender)

em=employee('sanu',30,21000,'male')
em.employee_details()
# Out:
# name of employee is sanu
# age of employee is 30
# salary of employee is 21000
# gender of employee is male

# %%
class student:
  school='abs school'

  def __init__(self,name,age,roll_num):
    self.name=name
    self.age=age
    self.roll_num=roll_num

  def details(self):
    print(f'{self.name} is {self.age} years old and studying at {self.school}.And roll number is {self.roll_num}')

student1=student('abishek',23,19)
student2=student('athul',24,25)
student1.details()
student2.details()
# Out:
# abishek is 23 years old and studying at abs school.And roll number is 19
# athul is 24 years old and studying at abs school.And roll number is 25

# %%
class character:
  def __init__(self,health,damage,power):
    self.health=health
    self.damage=damage
    self.power=power
ninja=character(300,40,80)
warrior=character(200,50,90)
print('power of ninja',ninja.power)
print('health of ninja',ninja.health)
print('damage of warrior',warrior.damage)
# Out:
# power of ninja 80
# health of ninja 300
# damage of warrior 50

# %%
class character:
  def __init__(self,health,damage,power):
    self.health=health
    self.damage=damage
    self.power=power
  def double(self):
    self.power=self.power*2
    self.damage=self.damage*3
abi=character(300,40,87)
sanu=character(200,30,82)
print('power of abi',abi.power)
print('health of abi',abi.health)
abi.double()
print('after doubling')
print('power of abi',abi.power)
print('damage of abi',abi.damage)
# Out:
# power of abi 87
# health of abi 300
# after doubling
# power of abi 174
# damage of abi 120

# %%
class character:
  def __init__(self,name,health,damage,power):
    self.name=name
    self.health=health
    self.damage=damage
    self.power=power
  def hai(self):
    print('hello i am',self.name)

  def is_alive(self):
    if self.health<=0:
      print(self.name,'is dead!')
    else:
      print(self.name,'is alive')

  def player_detail(self):
    print('.....'*5)
    print('name of player is',self.name)
    print("health of player is",self.health)
    print('damage of player is',self.damage)
    print('power of player is',self.power)
    print()

ninja=character('ninja',300,40,90)
warrior=character('warrior',200,30,80)

ninja.hai()
ninja.health=0
print('health of ninja',ninja.health)
ninja.is_alive()
warrior.is_alive()

warrior.player_detail()
ninja.player_detail()
# Out:
# hello i am ninja
# health of ninja 0
# ninja is dead!
# warrior is alive
# .........................
# name of player is warrior
# health of player is 200
# damage of player is 30
# power of player is 80
#
# .........................
# name of player is ninja
# health of player is 0
# damage of player is 40
# power of player is 90

# %%
x=2
print("The value is",x)
# Out:
# The value is 2

# %%
x=2
print(f"value is {x}")
# Out:
# value is 2

# %% [markdown]
# ## del operator
#
# we can delete the properites of the object or object itself by using the del keyword

# %%
class student:
  school='abs school'

  def __init__(self,name,age,roll_num):
    self.name=name
    self.age=age
    self.roll_num=roll_num

  def details(self):
    print(f'{self.name} is {self.age} years old and studying at {self.school}.And roll number is {self.roll_num}')

student1=student('abishek',23,19)
student2=student('athul',24,25)
del student1.name
student1.details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3039009818.py in <cell line: 0>()
#      14 del student1.name
#      15
# ---> 16 student1.details()
#
# /tmp/ipython-input-3039009818.py in details(self)
#       8
#       9   def details(self):
# ---> 10     print(f'{self.name} is {self.age} years old and studying at {self.school}.And roll number is {self.roll_num}')
#      11
#      12 student1=student('abishek',23,19)
#
# AttributeError: 'student' object has no attribute 'name'

# %% [markdown]
# ## Python built - in class function
#
#
# getattr ( obj, name, default ) :
#
# It is used to access the attribute of the object
#
# setattr ( obj, name, value ) :
#
# It is used to set a particular value to the specific attribute of an object
#
# delattr ( obj, name ) :
#
# it is used to delete a specific attribute.
#
# hasattr ( obj, name ) :
#
# It returns true if the object contains some specific attribute.

# %%
class student:
  school='abs school'

  def __init__(self,name,age,roll_num):
    self.name=name
    self.age=age
    self.roll_num=roll_num

  def details(self):
    print(f'{self.name} is {self.age} years old and studying at {self.school}.And roll number is {self.roll_num}')

student1=student('abishek',23,19)
student2=student('athul',24,25)
print(getattr(student1,'name'))   # or print(student1.name)

setattr(student1,'age',25)       # or student1.age=25
print(student1.age)

print(hasattr(student1,'id'))    # id attribute checking

delattr(student1,'age')      # for delete attribute
# Out:
# abishek
# 25
# False

# %% [markdown]
# # **Inheritance in oop**
#
#
# Inheritance is a fundemental concept of object-oriented programming(oop) that allows a class (child or derived class) to acquire the attributes and methods of another class (parent or base class), it facilitates code reusability, modularity, and the creation hierarchical relationships b/w classes. Promoting efficient code management and reducing redundancy.

# %% [markdown]
# ## Type of inheritance

# %% [markdown]
# ### single inheritance
#
# one parent and one child

# %%
class animal:        # parent class
  def speak(self):
    print('animal speaking')

class dog(animal):    # child class
   def bark(self):
    print('dog barking')

d=dog()
d.bark()
d.speak()

a=animal()
a.speak()
# a.bark()  AttributeError: 'Animal' object has no attribute 'bark' (because the orginal class have no connection with the child behaviour/child method)
# Out:
# dog barking
# animal speaking
# animal speaking

# %%
class vehicle:
  def start(self):
    print('vehicle is starting')
  def stop(self):
    print('vehicle is stoping')

class car(vehicle):
  def drive(self):
    print('car is being driven')

c=car()
c.start()
c.drive()
c.stop()
# Out:
# vehicle is starting
# car is being driven
# vehicle is stoping

# %%
class father:
  def sing(self):
    print('he is a singer')
  def draw(self):
    print('he can draw')

class son(father):
  def dance(self):
    print('he can dance')
  def piano(self):
    print('he is a pianoist')

s=son()
s.sing()
s.dance()
s.draw()
s.piano()

f=father()
# Out:
# he is a singer
# he can dance
# he can draw
# he is a pianoist

# %% [markdown]
# ### multilevel inheritance
#
#
# single parent, son, son's child

# %%
class animal:                         # parent class        or grandparent class
  def speak(self):
    print('animal is speaking')

class dog(animal):                    # child class    (inheritance)
  def bark(self):
    print('dog is barking')

class puppy(dog):                     # child son class   (multilevel inheritance)
  def eat(self):
    print('eating choco')

d=dog()
d.speak()
d.bark()
# d.eat()    AttributeError: 'dog' object has no attribute 'eat'
print()
p=puppy()
p.eat()
p.bark()
p.speak()
# Out:
# animal is speaking
# dog is barking
#
# eating choco
# dog is barking
# animal is speaking

# %%
class vehicle:
  def start(self):
    print('vehicle is starting')
  def stop(self):
    print('vehicle is stoping')

class car(vehicle):
  def breaking(self):
    print('car is breaking')

class bmw(car):
  def speed(self):
    print('high speed')

c=car()
c.breaking()
c.start()
c.stop()
print()
b=bmw()
b.breaking()
b.speed()
b.start()
b.stop()
# Out:
# car is breaking
# vehicle is starting
# vehicle is stoping
#
# car is breaking
# high speed
# vehicle is starting
# vehicle is stoping

# %% [markdown]
# ### hierarchial inheritance
#
# single parent class, more than one child class

# %%
class shape:                            # shape parent class
  def info(self):
    print('shape has dimension')

class circle(shape):                           # child of shape
  def draw(self):
    print('drawing a circle...')

class rectangle(shape):                     # also child of shape
  def draw(self):
    print('drawing a rectangle...')

c=circle()
r=rectangle()
c.info()
c.draw()
print()
r.info()
r.draw()
# Out:
# shape has dimension
# drawing a circle...
#
# shape has dimension
# drawing a rectangle...

# %%
class person:                       # parent
  def introduce(self):
    print("I am a person..")

class Teacher(person):              #child of person
  def teach(self):
    print("I teach students..")

class Student(person):              # also child of person
  def study(self):
    print("I study subjects")


t=Teacher()
s=Student()

t.introduce()
t.teach()
print()
s.introduce()
s.study()
# Out:
# I am a person..
# I teach students..
#
# I am a person..
# I study subjects

# %%
class vehicle:
  def move(self):
    print('vehicle is moving')

class car(vehicle):
  def stop(self):
    print('car is stoping')

class bike(vehicle):
  def wheel(self):
    print('bike has two wheels')


c=car()
b=bike()
c.move()
c.stop()
print()
b.move()
b.wheel()
# Out:
# vehicle is moving
# car is stoping
#
# vehicle is moving
# bike has two wheels

# %% [markdown]
# ### multiple inheritance
#
# multiple parent class , single child class

# %%
class Calculation1: # parent class
  def summation(self,a,b):
    print(a+b)

class Calculation2: # another parent class
  def multiplication(self,a,b):
    print(a*b)


class Derived(Calculation1,Calculation2):  # child from that both parent classes
  def divide(self,a,b):
    print(a/b)


d=Derived()
d.summation(10,20)
d.multiplication(10,20)
d.divide(10,20)
# Out:
# 30
# 200
# 0.5

# %%
class animal1:
  def catch(self):
    print('catching speed')

class animal2:
  def run(self):
    print('running speed')

class lion(animal1,animal2):
  def jump(self):
    print('jump very high')

l=lion()
l.catch()
l.run()
l.jump()
# Out:
# catching speed
# running speed
# jump very high

# %% [markdown]
# ### hybrid inheritance
#
# Hybrid inheritance is a **combination of two or more types of inheritance** (such as single, multiple, multilevel, or hierarchial inheritance ) in a single program.

# %%
class person:
  def show(self):
    print("I am a person")
class teacher(person):
  def teach(self):
    print("i teach students")

class staff:
  def manage(self):
    print("I manage school activities")

# hybrid inheritenc principal inherits from both teacher and staff (single + multiple)
class principal(teacher, staff):
  def oversea(self):
    print("I oversea the entire school")

principal = principal()
principal.show()
principal.teach()
principal.manage()
principal.oversea()
# Out:
# I am a person
# i teach students
# I manage school activities
# I oversea the entire school

# %% [markdown]
# ### super() method
#
# we can call parent method using super() function

# %%
class parent:
  def greet1(self):
    print("Hello from parent..")

class child(parent):
  def greet2(self):
    super().greet1()               # Calling parent method
    print("Hello from child..")

child=child()
child.greet2()
# Out:
# Hello from parent..
# Hello from child..

# %%
class parent:
  def __init__(self,name):
    self.name=name
    print("Parent constructor called..")

class child(parent):
  def __init__(self,name,age):
    super().__init__(name)
    self.age = age
    print("Child construnctor called..")

child=child("abishek",23)
# Out:
# Parent constructor called..
# Child construnctor called..

# %% [markdown]
# # polymorphism
#
#
# meaning one task can be performed in different ways. In Object-Oriented programming (oop), polymorphism allows the same method name to behave differently based on the object that calls it.

# %% [markdown]
# ## Type of polymorphism

# %% [markdown]
# ### method overriding
#
#
# A child class provides a specific implemntation of a method that is already defined in the parent class.

# %%
class A:
  def show(self):
    print('class A')

class B(A):
  def show(self):
    print('class B')

class C(B):
  def show(self):
    print('class C')

ob=C()
ob.show()
# Out:
# class C

# %%
class A:
  def show(self):
    print('class A')

class B(A):
  def show(self):
    super().show()
    print('class B')

class C(B):
  def show(self):
    super().show()
    print('class C')

ob=C()
ob.show()
# Out:
# class A
# class B
# class C

# %%
class animals:
  def speak(self):
    print('animal is making sound')

class dog(animals):
  def speak(self):
    print('dog barks')

class cat(animals):
  def speak(self):
    print('cat mewo')

d=dog()
c=cat()
d.speak()
c.speak()
# Out:
# dog barks
# cat mewo

# %% [markdown]
# ### method overloadind

# %% [markdown]
# Polymorphism in python allows different classes to have methods with the same name but different functionality. Method overloading means having multiple methods with the same name but different numbers or types of parameters.
#
# Default arguments - Providing default values to parameters.
# Variable - length arguments ( * args, ** kwargs ) - Allowing a method to acccept different numbersof arguments

# %% [markdown]
# default arguments

# %%
class calculator:
  def add(self,a,b=0,c=0):
    print(a+b+c)
# different number of argument
c=calculator()
c.add(5)
c.add(7,9)
c.add(2,4,6)
# Out:
# 5
# 16
# 12

# %% [markdown]
# variable - length argument(*args,**kwargs)

# %%
class maths:
  def add (self, *numbers):
    total = sum(numbers)
    print(f"Sum: {total}")

math = maths()

# call the method with n number of argumetns using (*args)

math.add(2)
math.add(4,5,1)
math.add(6,4,7,3)
math.add(25,14,25,12,14)
# Out:
# Sum: 2
# Sum: 10
# Sum: 20
# Sum: 90

# %%
class greeting:
  def say_hello(self, **kwargs):
    print(f"Hello {kwargs['name']}!")
    print(f"You are {kwargs['age']} years old!")
    print(f"You are from {kwargs['city']}!")

g=greeting()
g.say_hello(name='abishek',age=23,city='thrissur')
# Out:
# Hello abishek!
# You are 23 years old!
# You are from thrissur!

# %% [markdown]
# # Encapsulation

# %% [markdown]
# Encapsulation is one of the fundamental concepts in OOP that refers to binding data ( variables ) and methods ( fucntions ) that operate on the data into a single unit, and restriciting direct access to some of the object's components
#
# In simpler terms, Encapsulation is about protecting data by controlling access to it.
#
#     **Key Features of Encapsulation**:
#
# **Data Hiding :** Internal detailsof an object are
# hidden from the outside world
#
# **Access Controll :** Provides controlled access using public, private, and protected access specifiers.
#
# **Improved Security :** Prevents unathorized access and accidental modification of data
#
#
#
#     **Encapsulation Access Specifiers in Python :**
#
# **Public Members :** Accessible from anywhere.
#
# **Protected Members ( _variable ):** Intended for internal use but can be accessed with a warning
#
# **Private Members ( __variables ) :** Not accessible directly outside the class

# %%
class company:
  def __init__(self,company_name,company_id):
    self.__company_name=company_name
    self._company_id=company_id

c=company('tcs',54)
print(c._company_id)
# we can print one underscore variable
# print(c1.__company_name)               # we can't print two underscore variable outside the class
                                        #but we can access on the classs
# Out:
# 54

# %%
class company:
  def __init__(self,company_name,company_id):
    self.__company_name=company_name
    self._company_id=company_id

  def get_company_name(self):
    print(self.__company_name)

c=company('tcs',41)
c.get_company_name()
# Out:
# tcs

# %%
class bankaccount:
  def __init__(self,acct_no,balance):
    self.__acct_no=acct_no
    self.__balance=balance

  def deposite(self,amt):
    if amt>0:
      self.__balance +=amt
      print(f'deposite:{amt} new balance:{self.__balance}')
    else:
      print('invalid deposite error')

  def get_balance(self):
    return self.__balance

acct=bankaccount(215412,2000)
acct.deposite(200)
# print(acct.__balance) AttributeError: 'bankaccount' object has no attribute '_bankaccount__balance'
print(acct.get_balance())
# Out:
# deposite:200 new balance:2200
# 2200

# %% [markdown]
# # Abstraction

# %% [markdown]
# *   Abstraction is a concept in Object-Oriented Programming ( OOP ) that focuses on hiding the implementation details and showing only the necessary featyres of an object.
# *   It allows users to focus on what an object dows rather than how it does it.
#
#
# *   **Why is Abstraction important?**
#
# *   Simplifies complex systems by focusing only on essential aspects.
#
# *   Reduces code complexity and increases reusability.
#
#
# *  Enhances security by restricting direct acces to implementation details

# %% [markdown]
# **Abstraction in Python Using Abstract Class**es
#
#
# *   Python provides abstraction using abstract classes and abstract methods which are defined in the abc module
# *  Abstract class : A class that contains one or more abstract methods, ti cannot be instantiated directly.
#
# *   Abstrcat method : A method that is declared but contains no implementation ( must be implemented by child classses. )

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC): #abstract class

  @abstractmethod
  def start_engine(self):
    pass #abstract method with no implementation


  @abstractmethod
  def stop_engine(self):
    pass #abstract method with no implementation

# An abstract class cannot be instantiated directly
v=Vehicle() # TypeError: Can't instantiate abstract class Vehicle with abstract methods start_engine, stop_engine
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2671150894.py in <cell line: 0>()
#      13
#      14 # An abstract class cannot be instantiated directly
# ---> 15 v=Vehicle() # TypeError: Can't instantiate abstract class Vehicle with abstract methods start_engine, stop_engine
#
# TypeError: Can't instantiate abstract class Vehicle without an implementation for abstract methods 'start_engine', 'stop_engine'

# %% [markdown]
# If we want to make object from abstract class we can't directly make object from the abstract class.
#
# So we need to make child class for abstract class object making
#
# And also need to make same method ( function ) on child class also

# %%
from abc import ABC,abstractmethod
class vehicle(ABC):                 #abstract class

  @abstractmethod
  def start_engine(self):
    pass

  @abstractmethod
  def stop_engine(self):
    pass

    # making child class for abstract class instantiating

class car(vehicle):      # child class of vehicle

   def start_engine(self):      # also we need to create same function (method) in child class  other wise it will shows error!
    print("Car engine started")

   def stop_engine(self):
    print("Car engine stopped")

c=car()
c.start_engine()
c.stop_engine()
# Out:
# Car engine started
# Car engine stopped

# %%
from abc import ABC,abstractmethod

class shape(ABC):
   @abstractmethod
   def cal_area(self):
    pass

class circle(shape):
  def __init__(self,radius):
    self.radius=radius

  def cal_area(self):
    print('area=',3.14*(self.radius)**2)

class rectangle(shape):
  def __init__(self,length,width):
    self.length=length
    self.width=width

  def cal_area(self):
    print('area=',self.length*self.width)

c=circle(3)
c.cal_area()
print('.........')
r=rectangle(5,3)
r.cal_area()
# Out:
# area= 28.26
# .........
# area= 15

# %% [markdown]
# # Class method

# %% [markdown]
# Class methods can modify class-level variables or properties (variables shared among all instances).This allows changes to be made that affect the class as a whole, rather than just an individual instance.
#
# **( @classmethod ):** This is used to define a class method, it indicates that the method is bound to the class, not to an instance.
#
# **First Parameter (cls):** the first prameter of a class method is always a refernce to the class itself, typically named cls. This is similar to how instance methods have refernce to the instance ( typically names self ).

# %%
class car:
  wheels=4
  def __init__(self,brand,model):
    self.brand=brand
    self.model=model

  @classmethod
  def change_wheel(cls,newwheel):
    cls.wheels=newwheel
    print(f"the number of wheels are update to {cls.wheels}")

car1=car('toyota','etios')

# call the class method to modify the class variable
car.change_wheel(5)

print(f"car variable updated to :{car1.wheels}")
# Out:
# the number of wheels are update to 5
# car variable updated to :5

# %% [markdown]
# # Iterator

# %%
mytuple=('apple','banana','cherry')
it=iter(mytuple)
print(next(it))
print(next(it))
print(next(it))
# Out:
# apple
# banana
# cherry

# %%
my='apple'
it=iter(my)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# a
# p
# p
# l
# e

# %%
mytuple=('apple','banana','cherry')
for i in mytuple:
  print(i)
# Out:
# apple
# banana
# cherry

# %%
class mynum:
  def __iter__(self):
    self.a=1
    return self

  def __next__(self):
    x=self.a
    self.a +=1
    return x
mycls=mynum()
it=iter(mycls)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # Generator

# %%
def greeting():
  print('Hi!')
  yield 1
  print('how are you')
  yield 2
  print('are you there')
  yield 3
messenger=greeting()
result=next(messenger)
print(result)
result=next(messenger)
print(result)
result=next(messenger)
print(result)
# Out:
# Hi!
# 1
# how are you
# 2
# are you there
# 3

# %% [markdown]
# # **Threading**

# %% [markdown]
# Threading allows multiple parts of a prograrm to run concurrently.
#
# **Useful for tasks like:**
#
# Handling multiple user requests.
#
# Background tsks (eg. monitoring sensors).
#
# Downloading multiple files simultaneously.

# %% [markdown]
# **How to use Threading in Python**
#
# Import the threading module.
#
# Create threads using **threading.Thread( )**
#
# Start threads using ,**start( )**
#
# Wait for threads to **finish using .join( )**

# %%
# basic thread

import threading

def task():
  print('thread running')

thread= threading.Thread(target=task)
thread.start()
thread.join()
# Out:
# thread running

# %%
# multiple thread

import threading

def task1():
  print('task 1')

def task2():
  print('task 2')

a=threading.Thread(target=task1)
b=threading.Thread(target=task2)

a.start()
b.start()

a.join()
b.join()
# Out:
# task 1
# task 2

# %%
import threading

def number():
  for i in range(6):
    print(i)

t=threading.Thread(target=number)

t.start()
t.join()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
import threading
import time

def dwnld_file(file):
  print(f"dwnlding {file}..")
  time.sleep(2)
  print(f'{file}dwnloded.')

files=['file1.txt','file2.txt','file3.txt']

threads=[threading.Thread(target=dwnld_file,args=(f,))for f in files]

for t in threads:
  t.start()

for t in threads:
  t.join()
# Out:
# dwnlding file1.txt..
# dwnlding file2.txt..
# dwnlding file3.txt..
# file1.txtdwnloded.
# file2.txtdwnloded.
# file3.txtdwnloded.

# %% [markdown]
# ## using thread with arguments

# %%
import threading
def greet(name):
  print(f'hello {name}!')

t=threading.Thread(target=greet,args=('abishek',))
t.start()
t.join()
# Out:
# hello abishek!

# %% [markdown]
# ## two threading

# %%
import threading
import time
                   # thread 1
def chef_work():
  for i in range(5):               # chef prepares 5 dishes
    print(f'chef: preparing dish {i+1}....')
    time.sleep(2)                  # stimulate time taken to prepare dish
    if i==2:             # Assistant starts washing utensils during the 3rd dish
      print('chef: calling assistant to wash utensils.')
      time.sleep(1)                # Simulate time taken to call the assistant
      assistant_thread=threading.Thread(target=assistant_work)
      assistant_thread.start()
      assistant_thread.join()        # Wait for the assistant to finish
      print('chef: assistant done. resuming dish prepration.')
  print('chef: all dishes are prepared')

                   # thread 2
def assistant_work():
  for j in range(3):         # Assistant washes 3 utensils
    print(f' Assistant: Washing utensil {j+1}...')
    time.sleep(2)                   # Simulate time taken to wash each utensil
  print(" Assistant: All utensils are clean.")

print("Kitchen: Starting work.")
chef_thread = threading.Thread(target=chef_work)
chef_thread.start()
chef_thread.join()               # Wait for the chef to complete their work
print("Kitchen: All work completed.")
# Out:
# Kitchen: Starting work.
# chef: preparing dish 1....
# chef: preparing dish 2....
# chef: preparing dish 3....
# chef: calling assistant to wash utensils.
#  Assistant: Washing utensil 1...
#  Assistant: Washing utensil 2...
#  Assistant: Washing utensil 3...
#  Assistant: All utensils are clean.
# chef: assistant done. resuming dish prepration.
# chef: preparing dish 4....
# chef: preparing dish 5....
# chef: all dishes are prepared
# Kitchen: All work completed.

# %% [markdown]
# # **Exception**

# %% [markdown]
# Exception handling is a programming concept used to manage error or unexpected conditions that occure during the exicution of a programme .it alles the programe to continue running of failgracefully instead of crashing .

# %% [markdown]
# ***Use Exception Handling?***
#
# To prevent the entire program from crashing due to runtime errors.
#
# To provide informative error messages.
#
# To allow recovery or alternative execution paths.
#
# ***common terms***
#
# Exception: An error that occurs during program execution.
#
# Try block: Code that might throw an exception.
#
# Except block: Code that runs if an exception occurs.
#
# Finally block: Code that always runs, whether an exception occurred or not.
#
# Raise: Manually trigger an exception.

# %% [markdown]
# ## **What are errors?**

# %% [markdown]
# Errors are issues in the code that prevent it from executing successfully.
#
# **Types of Errors**
#
# Synatx Errors
#
# Runtime Erros
#
# Logical Errors

# %% [markdown]
# ### syntax error

# %% [markdown]
# Occur when the code vilates python's syntax rules.
#
# Detetcted before execution.
#
# Example: Missing colons, unmatched parentheses.

# %%
if 1>4
print('no')
# Out:
#   File "/tmp/ipython-input-3194519541.py", line 1
#     if 1>4
#           ^
# SyntaxError: expected ':'

# %% [markdown]
# ### Runtime error

# %% [markdown]
# Occur during program execution
#
# Example: Division by zero , accessing undefined variable
#
# Example Code Division by zero :
#
# x=1=/0 print(x)
#
# Error Message : zero Division Error : division by zero
#
# The program syntax is correct, but the operation fails at runtime(eg, dividing by zero, accessing an undefined variable , or file not found).

# %%
x=2/0
print(x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-1416212392.py in <cell line: 0>()
# ----> 1 x=2/0
#       2 print(x)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Logical error

# %% [markdown]
# The program runs but gives incorrect results due to logic false,
#
# Example: incorrect formula or condition.
#
# incorrect formula for calculating the area of a rectangle
#
# length =5
#
# width= 10
#
# area = length +width   # should be length * width
#
# print("Area;",area)
#
# ouput: Area :15
#
# The program runs successsfully but, the result is wrong because of a mistake in the logic of formula

# %%
try:
  num=int(input('enter a num:' ))
  result=10/num
except ZeroDivisionError:
  print("Cannot divide by zero!")
except ValuEError:
  print("Please enter a valid number!")
else:
  print("Division successful! Result:", result)
finally:
  print('this block always runs')
# Out:
# enter a num:0
# Cannot divide by zero!
# this block always runs

# %% [markdown]
# ## What are exceptions?

# %% [markdown]
# Exeptions are runtime errros that occur during program execution, disrupting the normal flow of a program
#
# Common Built-in Exceptions:
#
# ZeroDivisionErrors
#
# ValueError
#
# KeyError
#
# FileNotFoundError
#
# indexError

# %%
import math
print(math.exp(1000)) # its OverflowError
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipython-input-436628656.py in <cell line: 0>()
#       1 import math
# ----> 2 print(math.exp(1000)) # its OverflowError
#
# OverflowError: math range error

# %%
obj =42
obj.append(5) # Attruibute Error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2593622956.py in <cell line: 0>()
#       1 obj =42
# ----> 2 obj.append(5) # Attruibute Error
#
# AttributeError: 'int' object has no attribute 'append'

# %%
data= {"name":"john"}
print(data["age"])  # key Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2264199219.py in <cell line: 0>()
#       1 data= {"name":"john"}
# ----> 2 print(data["age"])  # key Error
#
# KeyError: 'age'

# %%
my_list=[1,2,3]
print(my_list[4]) # IndexError
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-928333831.py in <cell line: 0>()
#       1 my_list=[1,2,3]
# ----> 2 print(my_list[4]) # IndexError
#
# IndexError: list index out of range

# %%
print(int("hello")) # Value Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-238099271.py in <cell line: 0>()
# ----> 1 print(int("hello")) # Value Error
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
my_list=[1,2,3]
my_list.remove(5)   # value error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-782902140.py in <cell line: 0>()
#       1 my_list=[1,2,3]
# ----> 2 my_list.remove(5)
#
# ValueError: list.remove(x): x not in list

# %%
print("5"+5) #Type Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1682213241.py in <cell line: 0>()
# ----> 1 print("5"+5) #Type Error
#
# TypeError: can only concatenate str (not "int") to str

# %%
open("nonexistnt_file,.txt")  # FileNotFoundError
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-668679242.py in <cell line: 0>()
# ----> 1 open("nonexistnt_file,.txt")  # FileNotFoundError
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistnt_file,.txt'

# %%
try:
  open("nonexistnt_file.txt")
except FileNotFoundError as e:
  print(e)
# Out:
# [Errno 2] No such file or directory: 'nonexistnt_file.txt'

# %% [markdown]
# ## **Try - except error**
#
#
#
# Basis Structrue:
#
# (try: code that might raise an exception
#
# except Esception Type: code to handle the exception)

# %%
try:
  x= int (input("Eneter a number:"))
  y=10/x
  print(y)
except ZeroDivisionError:
  print("Cannot divide by zero")
# Out:
# Eneter a number:0
# Cannot divide by zero

# %%
try:
  x= int (input("Eneter a number:"))
  y=10/x
except ZeroDivisionError as e:
  print(e)
# Out:
# Eneter a number:0
# division by zero

# %%
try:
  print(a) # The a is not defined and it will show error
except:
  print("Error occured") # but there is exept keyword so that's why error not showing
# Out:
# Error occured

# %%
print(a)
print('hello world')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3083355263.py in <cell line: 0>()
# ----> 1 print(a)
#       2 print('hello world')
#
# NameError: name 'a' is not defined

# %%
try:
  print(a)
except:
  print('error occured')
print('hello world')
# Out:
# error occured
# hello world

# %% [markdown]
# ## else and finally block

# %% [markdown]
# ### else block
# Runs only if no exceptions occur.

# %%
try:
  num=int(input('enter a num:' ))
  result=10/num
except ZeroDivisionError:
  print("Cannot divide by zero!")
else:
  print(result)
# Out:
# enter a num:2
# 5.0

# %% [markdown]
# ### finally block
#
# Always runs, regardlesss of whether an exception occurred
# Useful for cleanup (ef, closing files)

# %%
try:
  file_= open("data.txt","r")

except FileNotFoundError:
  print("File not found!")

finally:
  print("End of program")
# Out:
# File not found!
# End of program

# %% [markdown]
# ## raise exception
#
# The raise statement in python is used to manually trigger an exception when a specific error condition occurs.

# %%
age = int(input("Enter your age:"))

if age<0:
  raise ValueError("Age cannot be negative")
else:
  print(f"Your age is {age}")

print("No try except")
# Out:
# Enter your age:-5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2273823197.py in <cell line: 0>()
#       2
#       3 if age<0:
# ----> 4   raise ValueError("Age cannot be negative")
#       5 else:
#       6   print(f"Your age is {age}")
#
# ValueError: Age cannot be negative

# %%
try:
  age = int(input("Enter your age:"))

  if age<0:
    raise ValueError("Age cannot be negative")
  else:
    print(f"Your age is {age}")
except ValueError as e:
  print(e)
print("try except finished")
# Out:
# Enter your age:-5
# Age cannot be negative
# try except finished

# %% [markdown]
# ## custom exception
#
# Custom exceptions are user- defined exceptions in Python that help handle domain-specific errors more meaningully and improve code clarity.

# %%
class invalidageexception(Exception):
  'raised when the input value is less than 18'
  pass

num=18
try:
  input_num=int(input('enter a number:'))
  if input_num < num:
    raise invalidageexception

  else:
    print('eligible to vote')

except invalidageexception:
  print('exception occured : invalid age')
# Out:
# enter a number:12
# exception occured : invalid age

# %% [markdown]
# # file handling

# %% [markdown]
# **Modes:**
#
# "r" – Read (default). Error if file doesn't exist.
#
# "w" – Write. Creates file if not exists, overwrites if it does.
#
# "a" – Append. Creates file if not exists, appends if it does.
#
# "x" – Create. Creates file, error if it exists.

# %%
file=open('exam.txt','x')
file.write("this file is created using 'x' mode.\n")
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipython-input-1032634724.py in <cell line: 0>()
# ----> 1 file=open('exam.txt','x')
#       2 file.write("this file is created using 'x' mode.\n")
#       3 file.close()
#
# FileExistsError: [Errno 17] File exists: 'exam.txt'

# %%
file=open('exam.txt','w')
file.write('hii python!\n')
file.write('this line is added.\n')
file.close()

# %%
file=open('exam.txt','a')
file.write('this file is appended.\n')
file.close()

# %%
file=open('exam.txt','r')
for line in file:
  print(line)
file.close()
# Out:
# hii python!
#
# this line is added.
#
# this file is appended.

# %% [markdown]
# Using **with** Statement
#
# Automatically handles closing the file.

# %%
with open('ab.txt','x') as file:
  file.write('hii!\n')

# %%
with open('ab.txt','w') as file:
  file.write('hello, world!\n')
  file.write('i am python\n')

# %%
with open('ab.txt','a') as file:
  file.write('programing language\n')

# %%
with open('ab.txt','r') as file:
  for i in file:
    print(i)
# Out:
# hello, world!
#
# i am python
#
# programing language

# %% [markdown]
# # Regular Expression

# %% [markdown]
# RegEx can be used to check if a string contains the specified search pattern

# %% [markdown]
# Python has a build in package called re, which can be used to work with regular expression
#
# `import re`

# %% [markdown]
# ## Metacharacters

# %%
import re

txt='the rain in spain'
#Find all lower case characters alphabetically between "a" and "h"

x=re.findall('[a-h]',txt)
print(x)
# Out:
# ['h', 'e', 'a', 'a']

# %%
import re

txt ="That will be 59 dollars"

#Find all digit characters

x=re.findall('\d',txt)
print(x)
# Out:
# ['5', '9']
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-2569625991.py:7: SyntaxWarning: invalid escape sequence '\d'
#   x=re.findall('\d',txt)

# %%
import re

txt = "hello planet"

#Search for a sequence that starts with "he", followed by two (any) characters, and an "o":

x = re.findall("he..o", txt)
print(x)
# Out:
# ['hello']

# %%
import re

txt = "hello planet"

#Check if the string starts with 'hello':

x = re.findall("^hello", txt)
if x:
  print("Yes, the string starts with 'hello'")
else:
  print("No match")
# Out:
# Yes, the string starts with 'hello'

# %%
import re

txt = "hello planet"

#Search for a sequence that starts with "he", followed by 0 or more  (any) characters, and an "e":

x = re.findall("he.*e", txt)

print(x)
# Out:
# ['hello plane']

# %%
import re

txt = "hello planet"

#Search for a sequence that starts with "he", followed by 1 or more  (any) characters, and an "a":

x = re.findall("he.+a", txt)

print(x)
# Out:
# ['hello pla']

# %%
import re

txt = "hello planet"

#Search for a sequence that starts with "he", followed by 0 or 1  character, and an "o":

x = re.findall("he.?o", txt)

print(x)

#This time we got no match, because there were not zero, not one, but two characters between "he" and the "o"
# Out:
# []

# %%
{} -	Exactly the specified number of occurrence

# %%
import re

txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains either "falls" or "stays"

x = re.findall("falls|stays", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['falls']
# Yes, there is at least one match!

# %% [markdown]
# ## RegEx funtion
#
#
#
# * The findall() function returns a list containing all matches
# * The search() function searches the string for a match, and returns a Match object if there is a match.
# If there is more than one match, only the first occurrence of the match will be returned:
#
#
#
# *   The split() function returns a list where the string has been split at each match:
# *   The sub() function replaces the matches with the text of your choice:

# %% [markdown]
# ### findall() function

# %%
import re

txt='the rain in spain'

x=re.findall('ai',txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
import re

txt='the rain in spain'

x=re.findall('india',txt)
if x:
  print('yes,match')
else:
  print('no match')
# Out:
# no match

# %% [markdown]
# ### search() funtion

# %%
import re

txt='india is my country'
x=re.search('spain',txt)
print(x)
# Out:
# None

# %%
import re

txt='india is my country'
x=re.search('\s',txt)
print(x.start())
# Out:
# 5
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-3172226200.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x=re.search('\s',txt)

# %% [markdown]
# ### split() funtion

# %%
import re

txt='india is my country'
x=re.split('is',txt)
print(x)
# Out:
# ['india ', ' my country']

# %%
import re

txt='india is my country'
x=re.split('\s',txt ,1)
print(x)
# Out:
# ['india', 'is my country']
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1244215558.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x=re.split('\s',txt ,1)

# %% [markdown]
# ### sub() funtion

# %%
import re

txt='india is my country'
x=re.sub('india','spain',txt)
print(x)
# Out:
# spain is my country

# %%
import re

txt='india is my country'
x=re.sub('\s','9',txt)
print(x)
# Out:
# india9is9my9country
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2812397892.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x=re.sub('\s','9',txt)

# %%
import re

txt='india is my country'
x=re.sub('\s','9',txt,2)
print(x)
# Out:
# india9is9my country
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-777999397.py:4: SyntaxWarning: invalid escape sequence '\s'
#   x=re.sub('\s','9',txt,2)

# %% [markdown]
# ### match object

# %%
import re

txt='india is my country'
x=re.search('ai',txt)
print(x)
# Out:
# None

# %%
import re

txt='The Rain in Spain'
x=re.search(r"\bR\w+",txt)
print(x.span())
# Out:
# (4, 8)

# %%
import re

txt='The rain in Spain'
x=re.search(r"\bT\w+",txt)
print(x.group())
# Out:
# The

# %%
import re

txt='The rain in Spain'
x=re.search(r"\bS\w+",txt)
print(x.string)
# Out:
# The rain in Spain

# %%
import re

txt='India is my Country'
x=re.search(r"\bis\b",txt)
print(x)
# Out:
# <re.Match object; span=(6, 8), match='is'>

# %%
import re

txt='India is my Country'
x=re.findall(r"\Bis\B",txt)
print(x)
# Out:
# []

# %%
import re

txt='India is my Country'
x=re.findall('is{2,}',txt)
print(x)
# Out:
# []

# %%
import re

txt='India is my Country'
x=re.findall('[art]',txt)
print(x)
# Out:
# ['a', 't', 'r']

# %%
import re

txt='India is my Country'
x=re.findall('[^abd]',txt)
print(x)
# Out:
# ['I', 'n', 'i', ' ', 'i', 's', ' ', 'm', 'y', ' ', 'C', 'o', 'u', 'n', 't', 'r', 'y']

# %%
import re

txt='India is my Country'
x=re.findall('[A-Z]',txt)
print(x)
# Out:
# ['I', 'C']

# %%
import re

txt='India is my Country'
x=re.search('y$',txt)
print(x)
# Out:
# <re.Match object; span=(18, 19), match='y'>

# %%
import re

txt='India is my Country'
x=re.findall('n.+',txt)
print(x)
# Out:
# ['ndia is my Country']
